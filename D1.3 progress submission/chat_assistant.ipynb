# %%
import json

# Opening JSON file
liza_f = open('datasets/chat/raw/лиза.json')

data = json.load(liza_f)
data['messages']
# Out:
# [{'id': 8232,
#   'type': 'message',
#   'date': '2023-08-02T11:36:22',
#   'date_unixtime': '1690965382',
#   'from': 'Администратор INNOPROG',
#   'from_id': 'user5790141925',
#   'photo': '(File not included. Change data exporting settings to download.)',
#   'width': 733,
#   'height': 1280,
#   'text': ['Добрый день! Отвечаем на вопрос: «',
#    {'type': 'italic', 'text': 'как скачать файд в pyCharm'},
#    '»\nВсе файлы проекта в PyCharm находятся в определённой папке этого проекта. Чтобы понять, где искать файл на устройстве, достаточно нажать правой кнопкой мыши на название открытого файла или сам файл, затем выбрать Open In и вам будет предложено открыть файл в папке. Так откроется папка с проектом, где вы и найдёте открытый файл.'],
#   'text_entities': [{'type': 'plain',
#     'text': 'Добрый день! Отвечаем на вопрос: «'},
#    {'type': 'italic', 'text': 'как скачать файд в pyCharm'},
#    {'type': 'plain',
# ...

# %%
messages = []

for msg in data['messages']:
    temp_dict = {'id': msg['id'], 'from': msg['from_id']}
    txt = ''
    for t in msg['text_entities']:
        txt += t['text']
    temp_dict['text'] = txt
    temp_dict['date'] = msg['date_unixtime']
    messages.append(temp_dict.copy())

messages
# Out:
# [{'id': 8232,
#   'from': 'user5790141925',
#   'text': 'Добрый день! Отвечаем на вопрос: «как скачать файд в pyCharm»\nВсе файлы проекта в PyCharm находятся в определённой папке этого проекта. Чтобы понять, где искать файл на устройстве, достаточно нажать правой кнопкой мыши на название открытого файла или сам файл, затем выбрать Open In и вам будет предложено открыть файл в папке. Так откроется папка с проектом, где вы и найдёте открытый файл.',
#   'date': '1690965382'},
#  {'id': 8233,
#   'from': 'user5790141925',
#   'text': 'Скажите, пожалуйста, у Вас получилось? Или нужна еще помощь',
#   'date': '1690972578'},
#  {'id': 8234,
#   'from': 'user273013296',
#   'text': 'Получилось, но отправляя файл в телеграм, пишет неверный ответ',
#   'date': '1690973284'},
#  {'id': 8235,
#   'from': 'user5790141925',
#   'text': 'Пришлите код, пожалуйста, который написали в файле',
#   'date': '1690973344'},
#  {'id': 8236,
#   'from': 'user273013296',
#   'text': 'Print(“Hello World”)',
# ...

# %%
len(messages)
# Out:
# 341

# %%
admin_id = 'user5790141925'
user_id = 'user273013296'
grouped = []
temp_dict = {'id': -1, 'from':user_id, 'text': questions[0], 'date': -1 }
grouped.append(temp_dict.copy())
temp_dict.clear()
text_temp = ''
for idx in range(1, len(messages)):

    if messages[idx-1]['from'] == messages[idx]['from']:
        text_temp += messages[idx-1]['text']
    else:
        text_temp += messages[idx-1]['text']
        temp_dict = {'id': messages[idx - 1]['id'], 'from': messages[idx - 1]['from'], 'text': text_temp, 'date': messages[idx - 1]['date'] }
        grouped.append(temp_dict.copy())
        text_temp = ''

grouped
# Out:
# [{'id': -1,
#   'from': 'user273013296',
#   'text': 'как скачать файд в pyCharm?',
#   'date': -1},
#  {'id': 8233,
#   'from': 'user5790141925',
#   'text': 'Добрый день! Отвечаем на вопрос: «как скачать файд в pyCharm»\nВсе файлы проекта в PyCharm находятся в определённой папке этого проекта. Чтобы понять, где искать файл на устройстве, достаточно нажать правой кнопкой мыши на название открытого файла или сам файл, затем выбрать Open In и вам будет предложено открыть файл в папке. Так откроется папка с проектом, где вы и найдёте открытый файл.Скажите, пожалуйста, у Вас получилось? Или нужна еще помощь',
#   'date': '1690972578'},
#  {'id': 8234,
#   'from': 'user273013296',
#   'text': 'Получилось, но отправляя файл в телеграм, пишет неверный ответ',
#   'date': '1690973284'},
#  {'id': 8235,
#   'from': 'user5790141925',
#   'text': 'Пришлите код, пожалуйста, который написали в файле',
#   'date': '1690973344'},
#  {'id': 8237,
#   'from': 'user273013296',
# ...

# %%
len(grouped)
# Out:
# 158

# %%
# dict_for_df = {'question': [], 'response':[], 'question_id':[], 'response_id':[], 'date':[]}
questions = []
responses = []
ids = []
resp_ids = []
dates = []
for i in range(len(grouped)//2):
    questions.append(grouped[i*2]['text'])
    responses.append(grouped[i*2+1]['text'])
    ids.append(grouped[i*2]['id'])
    resp_ids.append(grouped[i*2+1]['id'])
    dates.append(grouped[i*2]['date'])
    # dates.append(grouped[i*2+1]['date'])
dict_for_df = {'question': questions, 'response':responses, 'question_id':ids, 'response_id':resp_ids, 'date':dates}

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame.from_dict(dict_for_df)
df
# Out:
#                                              question  \
# 0                         как скачать файд в pyCharm?
# 1   Получилось, но отправляя файл в телеграм, пише...
# 2                                Print(“Hello World”)
# 3   добрый день! зачем ставить знак # перед числам...
# 4   Аааа поняла)\nНо зачем тогда она вообще нужна,...
# ..                                                ...
# 74  Да) Я просто очень хочу заниматься этим , по э...
# 75  ааа ну точно!я же пытаюсь не найти числа кратн...
# 76  Хорошо))добрый вечер! помогите с задачей, не п...
# 77  Ааа то есть тут не нужена строчка list(map(int...
# 78  добрый вечер! подскажите пожалуйста, в чем мож...
#
#                                              response  question_id  \
# 0   Добрый день! Отвечаем на вопрос: «как скачать ...           -1
# 1   Пришлите код, пожалуйста, который написали в ф...         8234
# 2   Отлично! Программа сохранена. Теперь этот файл...         8237
# ...

# %%
df.to_csv('datasets/chat/prepared/liza.csv')
